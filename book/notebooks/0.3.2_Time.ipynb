# %% [markdown]
# # 基準タイム

# %%
# %run 0.2_Function.ipynb

# %%
# 2021-2025 東京開催/芝/マイル
df = result_df("2015", "2025", ["東"])
cond = df["確定着順"] == 1
df = df[cond]
df_result = df[
    [
        "レースID",
        "馬名",
        "場所",
        "芝・ダ",
        "距離",
        "クラスコード",
        "馬場状態",
        "レース日",
        "走破タイム",
    ]
]
df_result.loc[:, "レースID"] = df_result["レースID"].astype(str)
mask = df_result["レースID"].str.len() == 9
# 先頭に "0" を付けて10桁に
df_result.loc[mask, "レースID"] = df_result.loc[mask, "レースID"].str.zfill(10)
# 馬番を削り8桁に
df_result.loc[:, "レースID"] = df_result["レースID"].str[:-2]

# %%
## 2021-2025 東京開催
df_time = time_df("2005", "2025", ["東"])
df_time["レースID"] = df_time["レースID"].astype(str)
mask = df_time["レースID"].str.len() == 7
# 先頭に "0" を付けて8桁に
df_time.loc[mask, "レースID"] = df_time.loc[mask, "レースID"].str.zfill(8)

# %%
df_joined = df_time.merge(
    df_result,
    how="left",
    on="レースID",
    suffixes=("", "_r"),
)

# %%
df_joined.sample(5)
# Out:
#          レースID   基準タイム               開催名  基準タイム(秒)              馬名   場所  芝・ダ  \
# 8312  05192302  1.26.9   2019年2回東京3日目 2R      86.9  ジーニー             東京    ダ
# 2667  05092611  1.31.8   2009年2回東京6日目11R      91.8             NaN  NaN  NaN
# 4174  05174510  2.08.3   2017年4回東京5日目10R     128.3       モンドアルジェンテ   東京    ダ
# 1974  05191801  2.16.6   2019年1回東京8日目 1R     136.6      ニューツーリズム     東京    ダ
# 4654  05142812  1.23.8   2014年2回東京8日目12R      83.8             NaN  NaN  NaN
#
#           距離  クラスコード 馬場状態       レース日  走破タイム
# 8312  1400.0     7.0    稍 2019-04-27   87.3
# 2667     NaN     NaN  NaN        NaT    NaN
# 4174  2100.0    67.0    不 2017-10-15  128.5
# 1974  2100.0     7.0    良 2019-02-17  135.9
# 4654     NaN     NaN  NaN        NaT    NaN

# %%
# 良馬場のマイルのみに絞る
cond = (df_joined["距離"] == 1600) & (df_joined["馬場状態"] == "良")
# TOP10
df_joined[cond].sort_values("走破タイム").head(20)
# Out:
#          レースID   基準タイム                開催名  基準タイム(秒)             馬名  場所 芝・ダ  \
# 8378  05192811  1.30.1    2019年2回東京8日目11R      90.1  ノームコア          東京   芝
# 8704  05202811  1.30.7    2020年2回東京8日目11R      90.7    アーモンドアイ      東京   芝
# 8774  05193211  1.30.6    2019年3回東京2日目11R      90.6     インディチャンプ    東京   芝
# 7058  05212811  1.31.1    2021年2回東京8日目11R      91.1     グランアレグリア    東京   芝
